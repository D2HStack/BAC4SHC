# %%
# Columns labels

COLUMNS_BA={
    'StartDate': 'start_date',
    'EndDate': 'end_date', 
    'Status': 'survey_status', # Not in data
    'Progress': 'completion_level',
    'Duration (in seconds)': 'completion_time', # Not sure
    'Finished': 'survey_completed', 
    'RecordedDate': 'recorded_date', # Not in data 
    'ResponseId': 'response_id', 
    'DistributionChannel': 'distribution_channel', # Not in data
    'UserLanguage': 'user_language', 
    'Q_RecaptchaScore': 'recaptcha_score', 
    'Q2.1': 'gender_male', 
    'Q2.2': 'age', 
    'Q2.3': 'children_num', 
    'Q2.4': 'edu_level',
    'Q2.5': 'edu_field', 
    'Q2.5_6_TEXT': 'edu_field_other', # Not ind data 
    'Q2.6': 'working_status', 
    'Q2.6_5_TEXT': 'working_status_other',
    'Q2.7': 'expertise_area', # Originally expertise_area_cat.
    'Q2.7_6_TEXT': 'expertise_area_other',
    'Q2.8': 'work_industries', 
    'Q2.8_9_TEXT': 'work_industries_other', 
    'Q2.9': 'work_company_size', # Originally work_companysize_experience.
    'Q2.10': 'roles_cat', 
    'Q3.1': 'inv_time', # Originally inv_time_since
    'Q3.2': 'inv_motivation', # Originally inv_motivation_cat
    'Q3.2_8_TEXT': 'inv_motivation_other',
    'Q3.3': 'ba_group', # Are you part of a business angel group or network? 
    'Q3.4': 'ba_group_name', # Which business angels' group or network do you belong to? (More than one option is possible)
    'Q3.4_5_TEXT': 'ba_group_name_other',
    'Q3.5': 'ba_group_reason', # Why did you choose to join a business angel group or network? (max 3 choices)
    'Q3.5_7_TEXT': 'ba_group_reason_other',
    'Q3.6': 'inv_num', 
    'Q3.7': 'inv_companies_last2y',
    'Q3.8': 'inv_amount_average',
    'Q3.9': 'inv_capital_stake', # What is your target % stake in a company's capital?
    'Q3.10': 'inv_dd_duration', # Originally inv_duediligence_duration
    'Q3.11': 'inv_criteria', # Originally inv_crieria_cat 
    'Q3.11_8_TEXT': 'inv_criteria_other', 
    'Q3.12': 'inv_sectors',
    'Q3.12_9_TEXT': 'inv_sectors_other', 
    'Q3.13': 'inv_process', # Not in data. How do you usually invest 
    'Q3.13_5_TEXT': 'inv_process_other', 
    'Q3.14': 'inv_visits', # Not in data. How many visits do you make on average to the companies you support?  
    'Q3.15': 'non_fin_contr', # What are your main non-financial contributions to invested companies? (max 3 options)
    'Q3.15_7_TEXT': 'non_fin_contr_other', 
    'Q3.16': 'child_bias', # On a scale from 1 to 5, how much do you think the number of your children affects your investment practices? 
    'Q3.17': 'inv_goal', 
    'Q3.18': 'inv_exit', 
    'Q3.19': 'inv_return', 
    'Q4.1_1': 'women_investing', 
    'Q4.1_2': 'women_involvement',
    'Q4.1_3': 'women_influence', 
    'Q4.2_1': 'women_diff_eval_process', 
    'Q4.2_2': 'women_risk_averse', # Originally women_riskadverse
    'Q4.3_1': 'women_evolution_involvement', 
    'Q4.3_2': 'women_evolution_neg_stereotype', # Originally women_evolution_negstereotype 
    'Q4.4': 'mother_needs_consideration', # How well do business angel groups/networks consider the unique needs of mothers? 
    'Q4.5': 'women_reco', # What actions would you recommend to business angel groups/networks to attract more women business angels? (max 3 options)
    'Q4.5_6_TEXT': 'women_reco_other', 
    'Q4.6': 'women_led_inv', # Originally womenled_invested_project
    'Q5.1': 'env_influence', # Originally env_influence_investments
    'Q5.2': 'env_inv', # Originally env_invested_projects 
    'Q5.3': 'env_aspects', 
    'Q5.3_7_TEXT': 'env_aspects_other', 
    'Q5.4': 'soc_influence', # Originally soc_influence_investments
    'Q5.5': 'soc_inv', # Originally soc_invested_projects 
    'Q5.6': 'soc_aspects', 
    'Q5.6_5_TEXT': 'soc_aspects_other', 
    'Q5.7': 'es_assess', 
    'Q5.7_4_TEXT': 'es_assess_other', 
    'Q5.8': 'es_more_info', 
    'Q5.9': 'es_certif', # Originally es_certif_cat
    'Q6.1': 'email', # You have completed the survey. Thank you for your precious participation! If you would like to receive updates on project results, please enter your e-mail address below.
}

COLUMNS_CI={
    'StartDate': 'start_date',
    'EndDate': 'end_date', 
    'Status': 'survey_status', # Not in data
    'Progress': 'completion_level',
    'Duration (in seconds)': 'completion_time', # Not sure
    'Finished': 'survey_completed', 
    'RecordedDate': 'recorded_date', # Not in data 
    'ResponseId': 'response_id', 
    'DistributionChannel': 'distribution_channel', # Not in data
    'UserLanguage': 'user_language', 
    'Q_RecaptchaScore': 'recaptcha_score', 
    'Q2.1': 'gender_male', 
    'Q2.2': 'age', 
    'Q2.3': 'children_num', 
    'Q2.4': 'edu_level',
    'Q2.5': 'edu_field', 
    'Q2.5_6_TEXT': 'edu_field_other', # Not ind data 
    'Q2.6': 'working_status', 
    'Q2.6_5_TEXT': 'working_status_other',
    'Q2.7': 'expertise_area', # Originally expertise_area_cat.
    'Q2.7_6_TEXT': 'expertise_area_other',
    'Q2.8': 'work_industries', 
    'Q2.8_9_TEXT': 'work_industries_other', 
    'Q2.9': 'work_company_size', # Originally work_companysize_experience.
    'Q2.10': 'roles_cat', 
    'Q3.1': 'inv_time', # Originally inv_time_since
    'Q3.2': 'inv_platform', # Which crowdfunding platform are you currently using? (Select the main one)
    'Q3.2_7_TEXT': 'inv_platform_other',
    'Q3.3': 'inv_motivation', # Originally inv_motivation_cat
    'Q3.3_7_TEXT': 'inv_motivation_other',
    'Q3.4': 'inv_num', 
    'Q3.5': 'inv_companies_last2y',
    'Q3.6': 'inv_amount_average',
    'Q3.7': 'inv_dd_duration', # Originally inv_duediligence_duration
    'Q3.8': 'inv_criteria', # Originally inv_crieria_cat 
    'Q3.8_7_TEXT': 'inv_criteria_other', 
    'Q3.9': 'inv_sectors',
    'Q3.9_9_TEXT': 'inv_sectors_other', 
    'Q3.10': 'inv_goal', 
    'Q3.11': 'inv_exit', 
    'Q3.12': 'inv_return', 
    'Q4.1_1': 'women_investing', 
    'Q4.1_2': 'women_involvement',
    'Q4.1_3': 'women_influence', 
    'Q4.2_1': 'women_diff_eval_process', 
    'Q4.2_2': 'women_risk_averse', # Originally women_riskadverse
    'Q4.3_1': 'women_evolution_involvement', 
    'Q4.3_2': 'women_evolution_neg_stereotype', # Originally women_evolution_negstereotype 
    'Q4.4': 'women_reco', # What actions would you recommend to crowdfunding platforms to attract more women crowd-investors? (max 3 options)
    'Q4.4_6_TEXT': 'women_reco_other', 
    'Q4.5': 'women_led_inv', # Originally womenled_invested_project
    'Q5.1': 'env_influence', # Originally env_influence_investments
    'Q5.2': 'env_inv', # Originally env_invested_projects 
    'Q5.3': 'env_aspects', 
    'Q5.3_7_TEXT': 'env_aspects_other', 
    'Q5.4': 'soc_influence', # Originally soc_influence_investments
    'Q5.5': 'soc_inv', # Originally soc_invested_projects 
    'Q5.6': 'soc_aspects', 
    'Q5.6_5_TEXT': 'soc_aspects_other', 
    'Q5.7': 'es_assess', 
    'Q5.7_5_TEXT': 'es_assess_other', 
    'Q5.8': 'es_more_info', 
    'Q5.9': 'es_certif', # Originally es_certif_cat
    'Q6.1': 'email', # You have completed the survey. Thank you for your precious participation! If you would like to receive updates on project results, please enter your e-mail address below.
}

# %%
# Upload
import pandas as pd 

file_paths=[
    "assets/datasets/source/BAC4SHC+survey+BA+10-2024_4+juin+2025_12.10.xlsx", # Business Angels
    "assets/datasets/source/BAC4SHC+survey+CI+10-2024_4+juin+2025_15.26.xlsx" # Crowdfunding
]
columns=[COLUMNS_BA, COLUMNS_CI]
surveys=['BA', 'CI'] # Metadata - Type of survey (BA= Business angels; CI=Crowd investors)

results=[]

for i in range(2):
    df_temp=pd.read_excel(file_paths[i])
    df_temp=(df_temp
            .drop(0) # The second row is labels in French
            .rename(columns=columns[i])
            )
    df_temp['survey']=surveys[i]
    results.append(df_temp)
# Out:
# d:\Projects\BAC4SHC\venv\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
# Concatenate BA and CI surveys
df_temp=pd.concat(results)

# %%
# Save the dataset

file_path='assets/datasets/clean/250604-consolidated_survey.xlsx'
df_temp.to_excel(file_path)
